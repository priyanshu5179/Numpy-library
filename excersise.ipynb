# %% [markdown]
# valid sudoku

# %%
s = np.array([
    [5, 3, 4, 6, 7, 8, 9, 1, 2],
    [6, 7, 2, 1, 9, 5, 3, 4, 8],
    [1, 9, 8, 3, 4, 2, 5, 6, 7],
    
    [8, 5, 9, 7, 6, 1, 4, 2, 3],
    [4, 2, 6, 8, 5, 3, 7, 9, 1],
    [7, 1, 3, 9, 2, 4, 8, 5, 6],
    
    [9, 6, 1, 5, 3, 7, 2, 8, 4],
    [2, 8, 7, 4, 1, 9, 6, 3, 5],
    [3, 4, 5, 2, 8, 6, 1, 7, 9]
])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 s = np.array([
#       2     [5, 3, 4, 6, 7, 8, 9, 1, 2],
#       3     [6, 7, 2, 1, 9, 5, 3, 4, 8],
#       4     [1, 9, 8, 3, 4, 2, 5, 6, 7],
#       5
#       6     [8, 5, 9, 7, 6, 1, 4, 2, 3],
#       7     [4, 2, 6, 8, 5, 3, 7, 9, 1],
#       8     [7, 1, 3, 9, 2, 4, 8, 5, 6],
#       9
#      10     [9, 6, 1, 5, 3, 7, 2, 8, 4],
#      11     [2, 8, 7, 4, 1, 9, 6, 3, 5],
#      12     [3, 4, 5, 2, 8, 6, 1, 7, 9]
#      13 ])
#
# NameError: name 'np' is not defined

# %%
s.sum()
# Out:
# np.int64(405)

# %%
a=s[0]
a.sum()
# Out:
# np.int64(45)

# %% [markdown]
# general question

# %%
import numpy as np

# Columns: [Age, Math Marks, Science Marks]
data = np.array([
    [18, 85, 78],   # Student 1
    [19, 92, 88],   # Student 2
    [17, 76, 95],   # Student 3
    [18, 65, 70],   # Student 4
    [20, 90, 85]    # Student 5
])

# %%
#Get the shape of the matrix.
data.shape
# Out:
# (5, 3)

# %% [markdown]
# #Find the average age of students.

# %%
a=data[:,0]
a
# Out:
# array([18, 19, 17, 18, 20])

# %%
a.mean()
# Out:
# np.float64(18.4)

# %% [markdown]
# #Extract Math marks of all students.

# %%
data[:,1]
# Out:
# array([85, 92, 76, 65, 90])

# %% [markdown]
# #Find the highest Science mark.

# %%
a=data[:,2]
a.max()
# Out:
# np.int64(95)

# %%
a
# Out:
# array([78, 88, 95, 70, 85])

# %% [markdown]
# #Get details of the student who scored more than 90 in Math.

# %%
data[1]
# Out:
# array([19, 92, 88])

# %% [markdown]
# #Increase Math marks of all students by 5.

# %%
a=data[:,1]
a*5
# Out:
# array([425, 460, 380, 325, 450])

# %%
a
# Out:
# array([85, 92, 76, 65, 90])

# %% [markdown]
# #Find how many students are younger than 19.

# %%
len(data[data[:,0]<19])
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 len(data[data[:,0]<19])
#
# NameError: name 'data' is not defined

# %%
a=np.mean(data[:,1:],axis=0)
a
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 a=np.mean(data[:,1:],axis=0)
#       2 a
#
# NameError: name 'np' is not defined
